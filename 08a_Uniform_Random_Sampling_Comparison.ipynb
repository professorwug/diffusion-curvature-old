# %%
#| default_exp comparisons
from nbdev.showdoc import *
import numpy as np
from tqdm.notebook import trange, tqdm
import matplotlib.pyplot as plt
import diffusion_curvature
from diffusion_curvature.core import plot_3d, diffusion_matrix, gaussian_kernel
from diffusion_curvature.gaussian_invariance import compute_anisotropic_diffusion_matrix_from_graph

# Reload any changes made to external files
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Curvature by Comparison
# > Anchoring Diffusion Curvature by comparison to a randomly sampled space of the same dimension

# %% [markdown]
# This notebook is a part of a suite of experiments answering the question: [Do Neural ODEs remove structure in a manner more conducive to curvature computations than pure random sampling](obsidian://advanced-uri?vault=Pumberton&uid=f3052b9e-cef0-4fb8-a4fd-fd150c7af868)?
#
# This notebook builds the simplest answer: comparing the diffusion curvature of a the manifold to a uniform random sampling of the same dimension.
# Obviously (and unfortunately), the dimension of the manifold must be supplied.
#
# To begin, here are the baseline functions for diffusion curvature:

# %%
#| export
import numpy as np
from scipy.stats import entropy
from diffusion_curvature.core import gaussian_kernel
from diffusion_curvature.gaussian_invariance import compute_anisotropic_diffusion_matrix_from_graph
def local_diffusion_entropy_of_matrix(
    P:np.ndarray, # diffusion matrix
    t:int # time step to compute entropy at
    ) -> np.ndarray:
    """Computes the pointwise entropy of the t-step diffusion, a proxy for curvature"""
    P_t = np.linalg.matrix_power(P,t)
    entropies = np.array([entropy(x) for x in P_t])
    return entropies
def diffusion_entropy_curvature_of_data(
        X:np.ndarray, # data points, in shape n x d
        t:int=8, # time steps of diffusion
        k:int=10, # number of neighbors to use in calculating kernel
        **kwargs
        )->np.ndarray:
    A = gaussian_kernel(X, kernel_type="adaptive",k=k)
    P = compute_anisotropic_diffusion_matrix_from_graph(A, alpha=1)
    entropies = local_diffusion_entropy_of_matrix(P,t=t)
    return entropies

# %% [markdown]
# ## Baseline: Entropy of the Torus
# To compare the local diffusion entropy of a dataset with that of other spaces, we need a sense of our tolerance for deviation. How much variance in the diffusion entropy reveals the curvature? Whatever method we choose must have a lower variance between random initializations than the intra-dataset variance of the torus.

# %%
from diffusion_curvature.datasets import torus
X_torus, ks_torus = torus(n=2000)
diffents_torus = diffusion_entropy_curvature_of_data(X_torus,t = 8, k=10) # using the default parameters

# %% [markdown]
# First, is this an accurate coloring of the torus? The colors will be inverted (low entropy -> positive curvature), but they should reveal the contour.

# %%
plot_3d(X_torus,diffents_torus)

# %%
plt.hist(diffents_torus)
variance_of_torus_entropies = np.var(diffents_torus)
print("Variance of entropies in torus is ", variance_of_torus_entropies)
# Out:
# Variance of entropies in torus is  0.03030868053439055

# %% [markdown]
# The difference between positive and negative curvature appears to span around 0.5 log units. Any comparison method should be well below that.

# %% [markdown]
# # Comparisons with Uniform Random Noise

# %%
#| export
def diffusion_entropy_of_noise(dimension, t, n_flat_samples) -> float:
    # construct uniform noise, with one zero point at the center
    noisy_flat = np.random.rand(n_flat_samples-1, dimension)*2 - 1
    noisy_flat = np.vstack([np.zeros(dimension),noisy_flat])
    # note that the edges of this distribution aren't trustworthy; we only care about the middle
    # so we'll take just the entropy of the random noise
    entropy_flat = diffusion_entropy_curvature_of_data(noisy_flat, t = t)
    # TODO: This is ridiculously wasteful. It computes the curvature of every point, when we only need
    # the central point.
    # At least average over some points
    return entropy_flat[0]

def diffusion_curvature_contra_noise(X, dimension, t=8, k=10) -> np.ndarray:
    k_data = diffusion_entropy_curvature_of_data(X, t=t)
    k_noise = diffusion_entropy_of_noise(dimension, t=t, n_flat_samples=len(X))
    return k_noise - k_data

# %% [markdown]
# ## Dimensionality Analysis
# Encounters with the curse of dimensionality

# %% [markdown]
# Let's see how the local diffusion entropy of flat noise changes as we increase the dimension

# %%
# ks = []
# n_flat_samples = 10000
# for dim in tqdm([2,3,4,5,6,7]):
#     ks.append(np.mean(diffusion_entropy_of_noise(dim, t=8, n_flat_samples=n_flat_samples)))

# %%
# plt.plot(ks)

# %% [markdown]
# It's likely that the decay observed here is caused by partially increasing mismatch between the dimension and the number of points sampled.
#
# Also, $ln(n\_points) = ln(10000) = 9.2$ is the maximum possible entropy. We converge to this quickly.

# %% [markdown]
# ## Testing the Variance of the Entropy of the noise
# This is a test of the robustness of the diffusion entropy method. One hopes that under repetition, the  entropy measurement won't change *too* much. Let's quantify exactly how much it does change.

# %%
n_tests = 500
n_samples = len(X_torus)
t = 8
ks_from_noise = []
for i in trange(n_tests):
    ks_from_noise.append(diffusion_entropy_of_noise(dimension=2, t=t, n_flat_samples=n_samples))
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/adjourner/Documents/4 SRC/4.21 SUMRY Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb Cell 19 in 6
#       <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> ks_from_noise = []
#       <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> for i in trange(n_tests):
# ----> <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a>     ks_from_noise.append(diffusion_entropy_of_noise(dimension=2, t=t, n_flat_samples=n_samples))
#
# /Users/adjourner/Documents/4 SRC/4.21 SUMRY Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb Cell 19 in 8
#       <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> noisy_flat = np.vstack([np.zeros(dimension),noisy_flat])
#       <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> # note that the edges of this distribution aren't trustworthy; we only care about the middle
#       <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a> # so we'll take just the entropy of the random noise
# ----> <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a> entropy_flat = diffusion_entropy_curvature_of_data(noisy_flat, t = t)
#       <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a> # TODO: This is ridiculously wasteful. It computes the curvature of every point, when we only need
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=9'>10</a> # the central point.
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=10'>11</a> # At least average over some points
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a> return entropy_flat[0]
#
# /Users/adjourner/Documents/4 SRC/4.21 SUMRY Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb Cell 19 in 2
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=13'>14</a> def diffusion_entropy_curvature_of_data(
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=14'>15</a>         X:np.ndarray, # data points, in shape n x d
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=15'>16</a>         t:int=8, # time steps of diffusion
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=16'>17</a>         k:int=10, # number of neighbors to use in calculating kernel
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=17'>18</a>         **kwargs
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=18'>19</a>         )->np.ndarray:
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=19'>20</a>     A = gaussian_kernel(X, kernel_type="adaptive",k=k)
# ---> <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=20'>21</a>     P = compute_anisotropic_diffusion_matrix_from_graph(A, alpha=1)
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=21'>22</a>     entropies = local_diffusion_entropy_of_matrix(P,t=t)
#      <a href='vscode-notebook-cell:/Users/adjourner/Documents/4%20SRC/4.21%20SUMRY%20Curvature/diffusion_curvature/08a_Uniform_Random_Sampling_Comparison.ipynb#X24sZmlsZQ%3D%3D?line=22'>23</a>     return entropies
#
# File ~/Documents/4 SRC/4.21 SUMRY Curvature/diffusion_curvature/diffusion_curvature/gaussian_invariance.py:22, in compute_anisotropic_diffusion_matrix_from_graph(A, alpha)
#      18 def compute_anisotropic_diffusion_matrix_from_graph(
#      19     A:np.ndarray, # the adjacency/affinity matrix of the graph
#      20     alpha:float, # the anisotropic density normalization parameter
#      21     ) -> np.ndarray:
# ---> 22     A_anis = compute_anisotropic_affinities_from_graph(A,alpha)
#      23     # row normalize to create diffusion matrix
#      24     D = np.diag(1/np.sum(A_anis,axis=1))
#
# File ~/Documents/4 SRC/4.21 SUMRY Curvature/diffusion_curvature/diffusion_curvature/gaussian_invariance.py:14, in compute_anisotropic_affinities_from_graph(A, alpha)
#       9 def compute_anisotropic_affinities_from_graph(
#      10     A:np.ndarray, # the adjacency/affinity matrix of the graph
#      11     alpha:float, # the anisotropic density normalization parameter
#      12 ) -> np.ndarray:
#      13     # normalize by density
# ---> 14     D = np.diag(1/np.sum(A,axis=1)**alpha)
#      15     A_anis = D @ A @ D
#      16     return A_anis
#
# File <__array_function__ internals>:180, in diag(*args, **kwargs)
#
# File ~/miniforge3/envs/diffusion_curvature/lib/python3.10/site-packages/numpy/lib/twodim_base.py:299, in diag(v, k)
#     297 if len(s) == 1:
#     298     n = s[0]+abs(k)
# --> 299     res = zeros((n, n), v.dtype)
#     300     if k >= 0:
#     301         i = k
#
# KeyboardInterrupt:

# %%
plt.hist(ks_from_noise)
# Out:
# (array([  6.,  22.,  40.,  94.,  93., 109.,  71.,  41.,  17.,   7.]),
#  array([5.87227446, 5.90998303, 5.9476916 , 5.98540017, 6.02310874,
#         6.06081731, 6.09852588, 6.13623445, 6.17394301, 6.21165158,
#         6.24936015]),
#  <BarContainer object of 10 artists>)

# %%
variance_of_randomly_sampled_entropies = np.var(ks_from_noise)
print("Variance of the data is",variance_of_randomly_sampled_entropies)
print("This is",variance_of_torus_entropies/variance_of_randomly_sampled_entropies, "times less than that between the entropies of the torus")
# Out:
# Variance of the data is 0.004586862501379477
# This is 7.282389434676444 times less than that between the entropies of the torus

# %% [markdown]
# This is actually low enough to be useful as a first approximation, at least within this regime of abundantly sampled data in low dimensions.

# %% [markdown]
# # Curvature by Comparison

# %%
ks_torus_contra_noise = diffusion_curvature_contra_noise(X_torus, dimension=2,t=8)

# %%
print("Lowest diffusion curvature value is ",min(ks_torus_contra_noise),"and highest is",max(ks_torus_contra_noise))
# Out:
# Lowest diffusion curvature value is  -0.36394522322790035 and highest is 0.4270823149220737

# %%
plot_3d(X_torus, ks_torus_contra_noise, title = "Diffusion Curvature (Contra Uniform Noise)")

# %% [markdown]
# Compared to the real curvatures

# %%
plot_3d(X_torus,ks_torus,title="Gaussian Curvature")

# %%
print("Lowest gaussian curvature value is ",min(ks_torus),"and highest is",max(ks_torus))
# Out:
# Lowest gaussian curvature value is  -1.9998186489767444 and highest is 1.333333316302257
